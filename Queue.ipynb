# %%
class queue1:
    queue=[]
    rear=-1
    mazsize=0
    front=0
    def createqueue(self,size):
        queue1.maxsize=size
        for i in range(size):
            queue1.queue.append(0)
        print("Stack created of size ,",len(queue1.queue))
        print(queue1.queue)
    def enqueue(self,e):
        queue1.rear+=1
        queue1.queue[queue1.rear]=e
        print("Element Pushed : ",e)
    def dequeue(self):
        temp=queue1.queue[queue1.front]
        queue1.front+=1
        return(temp)
    def isFull(self):
        if queue1.rear==queue1.maxsize-1:
            return True
        else:
            return False
    def isEmpty(self):
        if queue1.rear<queue1.front:
            return True
        else:
            return False
    def printqueue(self):
        print("Elements in the queue are : ",*queue1.queue[self.front:self.rear+1])

#main code
o=queue1()
o.createqueue(int(input("Enter Size : ")))
while True:
    print("1.enqued\n2.dequed\n3.print\n0.Exit")
    ch=int(input("Enter : "))
    if ch==1:
        if o.isFull()!=True:
            data=int(input("Enter data:"))
            o.enqueue(data)
        else:
            print("Queue Full")
    elif ch==2:
        if o.isEmpty()!=True:
            print("Element poped:",o.dequeue())
        else:
            print("queue Empty")
    elif ch==3:
        if o.isEmpty():
              print("queue is empty")
        else:
              o.printqueue()
    elif ch==0:
        print("Thank You")
        break
    else:
        print("Wrong Input :")
